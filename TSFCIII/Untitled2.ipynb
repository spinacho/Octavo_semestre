# %%
include("XY.jl")
# Out:
# INFO: Loading help data...

# %%
@time S,A=XY.montecarlo_config_run(100,10^7,0.1);
# Out:
# elapsed time: 7.020924986 seconds (588229728 bytes allocated, 6.81% gc time)

# %%
A
# Out:
# 859660

# %%
imshow(cos(S))
colorbar()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002637C7B8>)
# PyObject <matplotlib.colorbar.Colorbar instance at 0x0000000026547108>

# %%
figure(figsize=(15,15))
quiver(cos(S),sin(S))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D796978>)
# PyObject <matplotlib.quiver.Quiver object at 0x000000002D9C84A8>

# %%
@time XY.Mean_Magnetizations_T(20,10^6,[0.5:0.5:5.5])
# Out:
# elapsed time: 10.79756012 seconds (960307660 bytes allocated, 6.99% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000025FA3898>)
# PyObject <matplotlib.text.Text object at 0x00000000260B9630>
