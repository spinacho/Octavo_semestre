# %%
include("Final_XY.jl")

# %%
@time XY_2D.Mean_Plotter(50,10^6,[0.1:0.01:10])
# Out:
# elapsed time: 874.860082806 seconds (97604725760 bytes allocated, 8.14% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000244DC0B8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000025A80470>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000025A80518>)
# PyObject <matplotlib.text.Text object at 0x0000000025CC0E10>

# %%
@time XY_2D.plotter(50,10^7,0.1,true,true,false,false);
# Out:
# elapsed time: 9.012635882 seconds (830347304 bytes allocated, 4.91% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000004B9B8400>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000004B773278>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002B9F8B38>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000050F21D68>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002BD182B0>)

# %%
@time XY_2D.plotter(50,10^7,5,true,true,false,false);
# Out:
# elapsed time: 10.64858361 seconds (1077073256 bytes allocated, 6.09% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002BB14F60>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002B1D8470>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000004B87E4E0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002708E2E8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002B1FA0B8>)
