# %% [markdown]
# # MCMC para Ising

# %% [markdown]
# ## Ignacio Loaiza Gánem --- 412051272
# ##Rodrigo Leal Cervantes --- 411002099

# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %% [markdown]
# Mi Interact no está funcionando, por lo cual utilicé varias gráficas, lo siento.

# %% [markdown]
# En el notebook anterior, vimos cómo muestrear de una distribución de probabilidad $\pi$ dada, usando el algoritmo de Metropolis, que es un ejemplo de un método de "Markov Chain Monte Carlo" ("Monte Carlo usando cadenas de Markov",  MCMC).
# Apliquemos esto al modelo de Ising.

# %% [markdown]
# $\newcommand{\ss}{\pmb \sigma}
# \newcommand{\tt}{\pmb \tau}$
#
# [1] Escribe la probabilidad de aceptación, $\alpha(\ss \to \tt)$, para la distribución de Boltzmann, en términos de la diferencia de energías, $\Delta E := E(\tt) - E(\ss)$.

# %% [markdown]
# $$\alpha(\sigma\rightarrow\tau)=\frac{\pi(\tau)}{\pi(\sigma)}=e^{-\beta(E(\tau)-E(\sigma))}.$$

# %% [markdown]
# Llegamos entonces a que:
# $$\alpha(\sigma\rightarrow\tau)=e^{-\beta\Delta E}$$

# %% [markdown]
# [2] En el caso de voltear un solo espín, encuentra una expresión analítica para $\Delta E$, en términos del valor actual del espín que se va a voltear (antes de que se cambie su valor) y los valores de sus espines.

# %% [markdown]
# $$\Delta E=E(\tau)-E(\sigma)$$

# %% [markdown]
# Cada una de estas energías es una suma periódica. Como en $E(\tau)$ sólo cambiamos un espín, tenemos que en la resta se van a cancelar todas las componentes de la suma, menos las que están alrededor del espín. Estas, para $E(\sigma)$, son (siendo (i,j) las coordenadas del espín que cambiamos, y $S_{i,j}$ el espín (de $\sigma$) con coordenadas (i,j)):
# $$E(\sigma)=\Sigma+S_{i,j}(S_{i-1,j}+S_{i+1,j}+S_{i,j-1}+S_{i,j+1}),$$
# (tomando, cuando sea necesario algunos módulos).
# Y se tiene que:
# $$E(\tau)=\Sigma-S_{i,j}(S_{i-1,j}+S_{i+1,j}+S_{i,j-1}+S_{i,j+1}).$$
# Llegamos entonces a que:
# $$\Delta E=-2S_{i,j}(S_{i-1,j}+S_{i+1,j}+S_{i,j-1}+S_{i,j+1}).$$

# %% [markdown]
# [3] Así, implementa el algoritmo de Metropolis para simular el modelo de Ising a una temperatura $T$ dada.
#
# Nota que el resultado de la pregunta [2] muestra que, una vez propuesto un espín por voltear, *no* es necesario voltear el espín para calcular la $\Delta E$, y, por lo tanto, se requiere voltearlo *sólo* si el cambio propuesto resulte ser aceptado. Se puede voltear al modificar la misma configuración.

# %%
function config_maker(L::Int)
    
    S=zeros(L,L)
    
    for i in 1:L, j in 1:L
        if rand()<0.5
            S[i,j]=-1
        else
            S[i,j]=1
        end
    end
    
    return S
end;

# %%
conf

# %%
function spin_choose(L)
    
    i=rand(1:L)
    j=rand(1:L)
    
    return i,j
end;

# %%
function spin_flip!(S::Array,i,j,N=length(S),L=int(sqrt(N)))
    
    S[i,j]*=-1
    
    return S    
end;

# %%
function periodic_energy(S,N=length(S),L=int(sqrt(N)),J=1)
    
    E=0
    
    for i in 1:L, j in 1:L
        E+=S[i,j]*(S[mod1(i-1,L),j]+S[mod1(i+1,L),j]+S[i,mod1(j-1,L)]+S[i,mod1(j+1,L)])
    end
    
    return J*int(-E/2)
    
end;

# %%
function ΔE(S,i,j,N=length(S),L=int(sqrt(N)),J=1)
  
    return J*2*S[i,j]*(S[mod1(i+1,L),j]+S[mod1(i-1,L),j]+S[i,mod1(j-1,L)]+S[i,mod1(j+1,L)])
    
end;

# %%
function acceptance(S,T,i,j,N=length(S_old),L=int(sqrt(N)),J=1)
    
    Δe=ΔE(S,i,j,N,L,J)
    α=exp(-(1/T)*(Δe))
    
    if rand()<α
        return true,Δe
    else
        return false,0
    end
end;

# %%
function one_step_flip(S::Array,T,N=length(S),L=int(sqrt(N)),J=1)
    
    i,j=spin_choose(L)
    α,Δe=acceptance(S,T,i,j,N,L,J)
    if α==true
        spin_flip!(S,i,j,N,L)
        return Δe
    else
        return 0
    end
end;

# %%
function new_energy(E_old,Δe)
    
    return E_old+Δe
    
end;

# %%
function montecarlo_config_run(L::Int,steps::Int,T)
    N=L*L
    S=config_maker(L)

    for i in 1:steps
        one_step_flip(S,T,N,L,1)
    end
    
    return S
end;

# %%
for T in [0.5:0.5:3]
    figure()
    S=montecarlo_config_run(10,10^5,T)
    imshow(S)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002BC87EF0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002B6864A8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000026A04358>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C848A58>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002CD22CF8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002CE27400>)

# %% [markdown]
# Podemos ver cómo, cuando va aumentando la temperatura, todos los espínes tienden a estár más desordenados, mientras que a temperaturas bajas, tienden a ser casi todos el mismo.

# %% [markdown]
# [4] Durante la simulación, rastrea los valores de la magnetización $M(t)$ y la energía $E(t)$. Dibuja estas cantidades como función del tiempo.

# %%
function montecarlo_energy_run(L::Int,steps::Int,T)
    N=L*L
    S=config_maker(L)
    E=[periodic_energy(S)]
    sizehint(E,steps)

    for i in 1:steps
        Δe=one_step_flip(S,T,N,L,1)
        push!(E,new_energy(E[i],Δe))
    end
    
    return E
end;

# %%
magnetization(S)=sum(S);

# %%
function montecarlo_mag_run(L::Int,steps::Int,T)
    N=L*L
    S=config_maker(L)
    M=[magnetization(S)]
    sizehint(M,steps)

    for i in 1:steps
        one_step_flip(S,T,N,L,1)
        push!(M,magnetization(S))
    end
    
    return M
end;

# %%
@time for T in [0.5:0.5:3]
    figure()
    E=montecarlo_energy_run(50,10^5,T)
    plot(E)
    title("Energía a temperatura $T con respecto al tiempo")
    xlabel("Tiempo")
    ylabel("Energía")
end
# Out:
# elapsed time: 0.915157161 seconds (52363476 bytes allocated, 7.22% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D2DBB00>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002FD750B8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D7A4FD0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D7A4C18>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002FE80D30>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000300B56A0>)

# %%
@time for T in [0.5:0.5:3]
    figure()
    M=montecarlo_mag_run(10,10^5,T)
    plot(abs(M))
    title("Magnetización a temperatura $T con respecto al tiempo")
    xlabel("Tiempo")
    ylabel("Magnetización")
end
# Out:
# elapsed time: 0.652004478 seconds (31887984 bytes allocated, 4.66% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D133908>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D43D7B8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C9CA6A0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C9CA240>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C849C88>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C91E8D0>)

# %% [markdown]
# [5] Quisiéramos calcular estimados de valores promedio como $\langle E \rangle_\beta$. Viendo tus gráficas, propón cómo hacer esto e impleméntalo.

# %% [markdown]
# Vamos a calcular los valores promedio de las energías y de las magnetizaciones en función de la temperatura calculando el promedio de los arreglos de energía y de magnetizacipón obtenidos para una temperatura dada.

# %% [markdown]
# [6] Así, calcula $\langle E \rangle_\beta$ para distintos valores de $\beta$ entre $0$ y $5$, poniendo $J = 1$.

# %%
ET=Float64[]
T=[0.5:0.1:10]
sizehint(ET,length(T))
@time for temp in T
    E=montecarlo_energy_run(50,10^5,temp)
    push!(ET,mean(E))
end
plot(T,ET)
xlabel("Temperatura")
ylabel(L"Energia promedio $<E>_{T}$")
title("Energía promedio con respecto a la temperatura");
# Out:
# elapsed time: 4.889460948 seconds (978859088 bytes allocated, 14.74% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002CE340F0>)

# %%
ET=Float64[]
T=[0.5:0.01:10]
sizehint(ET,length(T))
@time for temp in T
    E=montecarlo_energy_run(50,10^6,temp)
    push!(ET,mean(E))
end
plot([1/t for t in T],ET)
xlabel(L"$\beta$")
ylabel(L"Energia promedio $<E>_{\beta}$")
title(L"Energia promedio con respecto a $\beta$");
# Out:
# elapsed time: 519.198517018 seconds (93822114736 bytes allocated, 15.39% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D4334A8>)

# %% [markdown]
# [7] Haz lo mismo con la magnetización. ¿Por qué no da un resultado interesante? ¿Qué podrías hacer al respecto? Impleméntalo y dibuja las gráficas.

# %%
MT=Float64[]
T=[0.5:0.5:10]
sizehint(MT,length(T))
for temp in T
    M=montecarlo_mag_run(100,10^6,temp)
    push!(MT,mean(M))
end
plot(T,MT,"o-")
xlabel("Temperatura")
ylabel(L"Magnetizacion promedio $<M>_{T}$")
title("Magnetización promedio con respecto a la temperatura");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C8C5DA0>)

# %% [markdown]
# Podemos ver que la magnetización parece "saltar". Esto se debe a que hay casos en los que casi todos los espines están hacia abajo, y otros en los que casi todos están hacia arriba. Esto es más notorio en las regiones de bajas temperaturas ya que los espines están más ordenados. Para arreglar esto, podemos tomar nada más el valor absoluto del promedio de la magnetización.

# %%
MT=Float64[]
T=[0.5:0.5:10]
sizehint(MT,length(T))
@time for temp in T
    M=montecarlo_mag_run(30,10^6,temp)
    push!(MT,mean(M))
end
plot(T,abs(MT),"o-")
xlabel("Temperatura")
ylabel(L"Valor absoluto de la magnetizacion promedio $|<M>_{T}|$")
title("Valor absoluto de la magnetización promedio con respecto a la temperatura \n");
# Out:
# elapsed time: 15.203806828 seconds (989939728 bytes allocated, 3.94% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C9B6C88>)

# %% [markdown]
# [8] Cambia gradualmente la temperatura inversa de $5$ a $0$ y haz una animación de algunas **configuraciones** representativas para distintas temperaturas.

# %%
@time for T in [0.1:0.1:3.5]
    figure()
    S=montecarlo_config_run(100,10^6,T)
    imshow(S)
end
# Out:
# elapsed time: 13.049673628 seconds (1244885256 bytes allocated, 6.75% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000028096AC8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002FD74278>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030AC6E48>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002FD9CF60>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D76B080>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000300C6518>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D63A208>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000304A0BA8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003049D080>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030A79898>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030917710>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030631A90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000304588D0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D377550>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000309C72E8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030878080>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D4C2160>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C9D0C18>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D7101D0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000033DB4E10>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002C8C5080>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000269F2358>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002CD5A6A0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D3DA550>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030288198>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002D21DEF0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002FC74C50>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000003034DD68>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000354BE588>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000355CA550>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000033E6D748>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000033F399B0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000033FA4F28>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000034143DD8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000034219C50>)

# %% [markdown]
# [9] Interpreta todo esto físicamente. ¿Qué estamos viendo?

# %% [markdown]
# Podemos ver cómo, a bajas temperaturas, todos los espines tienden a estar en el mismo estado, sea que tenemos un cierto grado de orden en el sistema. Cuando la temperatura va subiendo, el grado de desorden del sistema va aumentando: la energía también aumenta, pero la magnetización disminuye ya que los espines se vuelven mucho más aleatorios.
