# %%
include("Ising.jl")

# %%
i=int8(1)
# Out:
# 1

# %%
Ising.config_maker(2,5)
# Out:
# Spin_Configuration(2,4,5.0,2x2 Array{Int8,2}:
#  -1  -1
#  -1  -1,0.2,1.0,8,-4)

# %%
@time E=Ising.montecarlo_energy_run(50,10^6,0.1);
# Out:
# elapsed time: 0.474182757 seconds (50375788 bytes allocated, 20.83% gc time)

# %%
plot(E)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000056EDF5F8>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000043F65F98>

# %%
@time Ising.Mean_Energies_T(50,10^6,[0.5:0.1:10])
# Out:
# elapsed time: 37.181195525 seconds (4761005004 bytes allocated, 13.63% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000056EC3630>)
# PyObject <matplotlib.text.Text object at 0x0000000057D433C8>

# %%
@time Ising.Mean_Abs_Magnetizations(10,10^6,[0.5:0.1:10])
# Out:
# elapsed time: 30.717769273 seconds (4875750208 bytes allocated, 13.54% gc time)
# elapsed time: 30.777911402 seconds (4875784028 bytes allocated, 13.51% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000056E37320>)
# PyObject <matplotlib.text.Text object at 0x0000000056ED6358>
