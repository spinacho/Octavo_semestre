# %%
x=5
# Out:
# 5

# %%
31%30
# Out:
# 1

# %%
include("Final_XY.jl")

# %%
@time XY_2D.Mean_Plotter(50,10^6,[0.5:0.1:10])
# Out:
# elapsed time: 90.646096882 seconds (9523793788 bytes allocated, 8.41% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000029EFD160>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002A4316D8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000029C832E8>)
# PyObject <matplotlib.text.Text object at 0x000000002979F438>

# %%
@time MATS=XY_2D.config_teller_for_anim(10,10^6,10^4,0.5);
# Out:
# elapsed time: 0.725108881 seconds (62155120 bytes allocated, 10.30% gc time)
