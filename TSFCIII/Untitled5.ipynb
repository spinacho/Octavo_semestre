# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
include("Final_XY.jl")

# %%
@time S,E,M,A=XY_3D.config_runner(5,10^5,1);
# Out:
# elapsed time: 0.137941215 seconds (9267728 bytes allocated)

# %%
@time XY_3D.Mean_Plotter(50,10^6,[0.01:0.001:0.1])
# Out:
# elapsed time: 126.933369717 seconds (9863142316 bytes allocated, 5.21% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002F0BE0F0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000034B8EDD8>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000035362978>)
# PyObject <matplotlib.text.Text object at 0x00000000357B09E8>

# %%
@time XY_3D.Mean_Plotter(50,10^6,[0.1:0.01:10])
# Out:
# elapsed time: 1447.61615775 seconds (124062452620 bytes allocated, 5.80% gc time)
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000034DBBF60>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000351B5A90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000349D0198>)
# PyObject <matplotlib.text.Text object at 0x000000002EC73F60>
